# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print('Beginning Data Retrieval')
print('-----------------------------')
# Get weather data

#Set up lists to hold reponse info

record_number = 1
set_number = 1
city_data = []
for i, city in enumerate(cities):
    if (i %50 == 0 and i >= 50 ):
        set_number +=1 
        record_number =0
    print(f'Processing Record {record_number} of Set {set_number} | {city}' )
    record_number +=1
    try:
        weather_response = requests.get(query_url + city).json()

        cloudiness = weather_response['clouds']['all']
        country = weather_response['sys']['country']
        date = weather_response['dt']
        humidity = weather_response['main']['humidity']
        lat = weather_response['coord']['lat']
        lng = weather_response['coord']['lon']
        max_tem = weather_response['main']['temp_max']
        wind_speed = weather_response['wind']['speed']
        city_data.append({ "City": city,
                           "Cloudiness": cloudiness,
                            "Country": country,
                            "Date": date,
                            "Humidity": humidity,
                            "Lat": lat,
                            "Lng":lng,
                            "Max Temp": max_tem,
                            "Wind Speed": wind_speed})
    except:
        print('city not found. Skipping city')
        pass
# Inform that Data Retrieval was Completed
print('-----------------------------')
print('Data Retrieval Complete')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kruisfontein
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | katsuura
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | amderma
# city not found. Skipping city
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | aksarka
# Processing Record 10 of Set 1 | belushya guba
# city not found. Skipping city
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | illoqqortoormiut
# city not found. Skipping city
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | sloboda
# Processing Record 17 of Set 1 | taolanaro
# city not found. Skipping city
# Processing Record 18 of Set 1 | saint anthony
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | attawapiskat
# city not found. Skipping city
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | fare
# Processing Record 24 of Set 1 | pokhara
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | oistins
# Processing Record 28 of Set 1 | zeya
# Processing Record 29 of Set 1 | caohai
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | touba
# Processing Record 33 of Set 1 | wamba
# Processing Record 34 of Set 1 | palmer
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | channel-port aux basques
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | nalut
# Processing Record 40 of Set 1 | kayes
# Processing Record 41 of Set 1 | buala
# Processing Record 42 of Set 1 | rodrigues alves
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | namatanai
# Processing Record 48 of Set 1 | persianovskiy
# Processing Record 49 of Set 1 | borzya
# Processing Record 50 of Set 1 | isangel
# Processing Record 0 of Set 2 | luganville
# Processing Record 1 of Set 2 | sortland
# Processing Record 2 of Set 2 | mujiayingzi
# Processing Record 3 of Set 2 | miechow
# Processing Record 4 of Set 2 | khatanga
# Processing Record 5 of Set 2 | chengmai
# city not found. Skipping city
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | pokosnoye
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | awbari
# Processing Record 10 of Set 2 | puerto vallarta
# Processing Record 11 of Set 2 | port macquarie
# Processing Record 12 of Set 2 | ilo
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | vila velha
# Processing Record 15 of Set 2 | sinnai
# Processing Record 16 of Set 2 | sarahan
# Processing Record 17 of Set 2 | nizhnyaya pavlovka
# city not found. Skipping city
# Processing Record 18 of Set 2 | lock haven
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | pesnica pri mariboru
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | anadyr
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | necochea
# Processing Record 27 of Set 2 | samusu
# city not found. Skipping city
# Processing Record 28 of Set 2 | balarampur
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | leh
# Processing Record 31 of Set 2 | puksoozero
# Processing Record 32 of Set 2 | hualmay
# Processing Record 33 of Set 2 | tambura
# Processing Record 34 of Set 2 | kyshtovka
# Processing Record 35 of Set 2 | yulara
# Processing Record 36 of Set 2 | oyama
# Processing Record 37 of Set 2 | havelock
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | belyy yar
# Processing Record 40 of Set 2 | columbus
# Processing Record 41 of Set 2 | port-gentil
# Processing Record 42 of Set 2 | shahr-e kord
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | sistranda
# Processing Record 45 of Set 2 | edd
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | campo maior
# Processing Record 49 of Set 2 | bluff
# Processing Record 0 of Set 3 | oliveira dos brejinhos
# Processing Record 1 of Set 3 | port lincoln
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | haines junction
# Processing Record 4 of Set 3 | srivaikuntam
# Processing Record 5 of Set 3 | muisne
# Processing Record 6 of Set 3 | codrington
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | pevek
# Processing Record 9 of Set 3 | volosovo
# Processing Record 10 of Set 3 | lamu
# Processing Record 11 of Set 3 | dunedin
# Processing Record 12 of Set 3 | barentsburg
# city not found. Skipping city
# Processing Record 13 of Set 3 | windhoek
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | tsihombe
# city not found. Skipping city
# Processing Record 16 of Set 3 | kalyazin
# Processing Record 17 of Set 3 | cabatuan
# Processing Record 18 of Set 3 | stonewall
# Processing Record 19 of Set 3 | nouadhibou
# Processing Record 20 of Set 3 | yenagoa
# Processing Record 21 of Set 3 | artyk
# city not found. Skipping city
# Processing Record 22 of Set 3 | kohlu
# Processing Record 23 of Set 3 | samarai
# Processing Record 24 of Set 3 | wulanhaote
# city not found. Skipping city
# Processing Record 25 of Set 3 | montoro
# Processing Record 26 of Set 3 | dzilam gonzalez
# Processing Record 27 of Set 3 | nome
# Processing Record 28 of Set 3 | takhtamygda
# Processing Record 29 of Set 3 | ucluelet
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | salalah
# Processing Record 32 of Set 3 | srednekolymsk
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | husavik
# Processing Record 35 of Set 3 | lorengau
# Processing Record 36 of Set 3 | kalabo
# Processing Record 37 of Set 3 | albany
# Processing Record 38 of Set 3 | cockburn town
# Processing Record 39 of Set 3 | beringovskiy
# Processing Record 40 of Set 3 | celestun
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | svetlogorsk
# Processing Record 43 of Set 3 | hovd
# Processing Record 44 of Set 3 | fayaoue
# Processing Record 45 of Set 3 | la moncada
# Processing Record 46 of Set 3 | hofn
# Processing Record 47 of Set 3 | chernyshevskiy
# Processing Record 48 of Set 3 | juxtlahuaca
# Processing Record 49 of Set 3 | komsomolskiy
# Processing Record 0 of Set 4 | ekhabi
# Processing Record 1 of Set 4 | bathsheba
# Processing Record 2 of Set 4 | hami
# Processing Record 3 of Set 4 | duliagaon
# Processing Record 4 of Set 4 | suna
# Processing Record 5 of Set 4 | jujuy
# city not found. Skipping city
# Processing Record 6 of Set 4 | jaszkiser
# Processing Record 7 of Set 4 | meulaboh
# Processing Record 8 of Set 4 | ahipara
# Processing Record 9 of Set 4 | flinders
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | kendari
# Processing Record 12 of Set 4 | dikson
# Processing Record 13 of Set 4 | coahuayana
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | kavaratti
# Processing Record 16 of Set 4 | dubbo
# Processing Record 17 of Set 4 | ukiah
# Processing Record 18 of Set 4 | ancud
# Processing Record 19 of Set 4 | lasa
# Processing Record 20 of Set 4 | iqaluit
# Processing Record 21 of Set 4 | iguape
# Processing Record 22 of Set 4 | saint-joseph
# Processing Record 23 of Set 4 | atasu
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | marcona
# city not found. Skipping city
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | joson
# Processing Record 28 of Set 4 | aasiaat
# Processing Record 29 of Set 4 | acapulco
# Processing Record 30 of Set 4 | axim
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | kilinochchi
# Processing Record 33 of Set 4 | manono
# Processing Record 34 of Set 4 | ambunti
# Processing Record 35 of Set 4 | pisco
# Processing Record 36 of Set 4 | bambous virieux
# Processing Record 37 of Set 4 | san felipe
# Processing Record 38 of Set 4 | nemuro
# Processing Record 39 of Set 4 | saskylakh
# Processing Record 40 of Set 4 | rebrikha
# Processing Record 41 of Set 4 | tricase
# Processing Record 42 of Set 4 | rijeka
# Processing Record 43 of Set 4 | kasongo-lunda
# Processing Record 44 of Set 4 | barrow
# Processing Record 45 of Set 4 | cacoal
# Processing Record 46 of Set 4 | avarua
# Processing Record 47 of Set 4 | ordu
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | lavrentiya
# Processing Record 0 of Set 5 | stornoway
# Processing Record 1 of Set 5 | rantauprapat
# Processing Record 2 of Set 5 | nyurba
# Processing Record 3 of Set 5 | stephenville
# Processing Record 4 of Set 5 | cidreira
# Processing Record 5 of Set 5 | pailon
# Processing Record 6 of Set 5 | dubrovnik
# Processing Record 7 of Set 5 | sentyabrskiy
# city not found. Skipping city
# Processing Record 8 of Set 5 | changji
# Processing Record 9 of Set 5 | gidam
# Processing Record 10 of Set 5 | sorong
# Processing Record 11 of Set 5 | kahului
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | aklavik
# Processing Record 14 of Set 5 | coihaique
# Processing Record 15 of Set 5 | puerto ayora
# Processing Record 16 of Set 5 | yumen
# Processing Record 17 of Set 5 | vaitupu
# city not found. Skipping city
# Processing Record 18 of Set 5 | newport
# Processing Record 19 of Set 5 | gerash
# Processing Record 20 of Set 5 | chuy
# Processing Record 21 of Set 5 | kupang
# Processing Record 22 of Set 5 | nizhneyansk
# city not found. Skipping city
# Processing Record 23 of Set 5 | neuquen
# Processing Record 24 of Set 5 | khasan
# Processing Record 25 of Set 5 | sierpc
# Processing Record 26 of Set 5 | dicabisagan
# Processing Record 27 of Set 5 | da nang
# Processing Record 28 of Set 5 | turbat
# Processing Record 29 of Set 5 | ingham
# Processing Record 30 of Set 5 | marawi
# Processing Record 31 of Set 5 | yandoon
# city not found. Skipping city
# Processing Record 32 of Set 5 | vestmannaeyjar
# Processing Record 33 of Set 5 | fairbanks
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | bilma
# Processing Record 36 of Set 5 | xuddur
# Processing Record 37 of Set 5 | samdari
# Processing Record 38 of Set 5 | lagos
# Processing Record 39 of Set 5 | rio gallegos
# Processing Record 40 of Set 5 | yining
# Processing Record 41 of Set 5 | ardakan
# Processing Record 42 of Set 5 | olinda
# Processing Record 43 of Set 5 | vitim
# Processing Record 44 of Set 5 | pacific grove
# Processing Record 45 of Set 5 | karratha
# Processing Record 46 of Set 5 | bireun
# Processing Record 47 of Set 5 | tura
# Processing Record 48 of Set 5 | acarau
# Processing Record 49 of Set 5 | saldanha
# Processing Record 0 of Set 6 | siniscola
# Processing Record 1 of Set 6 | uthal
# Processing Record 2 of Set 6 | mount isa
# Processing Record 3 of Set 6 | miri
# Processing Record 4 of Set 6 | clyde river
# Processing Record 5 of Set 6 | bensonville
# Processing Record 6 of Set 6 | vardo
# Processing Record 7 of Set 6 | bumba
# Processing Record 8 of Set 6 | sirnak
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | vostok
# Processing Record 11 of Set 6 | tabou
# Processing Record 12 of Set 6 | kerman
# Processing Record 13 of Set 6 | saint combs
# city not found. Skipping city
# Processing Record 14 of Set 6 | chandbali
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | port hedland
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | inhambane
# Processing Record 19 of Set 6 | zhangye
# Processing Record 20 of Set 6 | hasaki
# Processing Record 21 of Set 6 | kon tum
# Processing Record 22 of Set 6 | gat
# Processing Record 23 of Set 6 | aykhal
# Processing Record 24 of Set 6 | uray
# Processing Record 25 of Set 6 | narsaq
# Processing Record 26 of Set 6 | udachnyy
# Processing Record 27 of Set 6 | kuche
# city not found. Skipping city
# Processing Record 28 of Set 6 | qorveh
# Processing Record 29 of Set 6 | qafsah
# city not found. Skipping city
# Processing Record 30 of Set 6 | ixtapa
# Processing Record 31 of Set 6 | cabo san lucas
# Processing Record 32 of Set 6 | labutta
# city not found. Skipping city
# Processing Record 33 of Set 6 | provideniya
# Processing Record 34 of Set 6 | mama
# Processing Record 35 of Set 6 | san quintin
# Processing Record 36 of Set 6 | jumla
# Processing Record 37 of Set 6 | vila
# Processing Record 38 of Set 6 | dunda
# Processing Record 39 of Set 6 | marsh harbour
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | leshukonskoye
# Processing Record 42 of Set 6 | sao jose da coroa grande
# Processing Record 43 of Set 6 | palana
# Processing Record 44 of Set 6 | san jose
# Processing Record 45 of Set 6 | port elizabeth
# Processing Record 46 of Set 6 | osa
# Processing Record 47 of Set 6 | ca mau
# Processing Record 48 of Set 6 | plonsk
# Processing Record 49 of Set 6 | nakhon thai
# Processing Record 0 of Set 7 | ewa beach
# Processing Record 1 of Set 7 | chapais
# Processing Record 2 of Set 7 | touros
# Processing Record 3 of Set 7 | coquimbo
# Processing Record 4 of Set 7 | alexandria
# Processing Record 5 of Set 7 | thai binh
# Processing Record 6 of Set 7 | kanye
# Processing Record 7 of Set 7 | bani walid
# Processing Record 8 of Set 7 | berlevag
# Processing Record 9 of Set 7 | praya
# Processing Record 10 of Set 7 | grand gaube
# Processing Record 11 of Set 7 | grand river south east
# city not found. Skipping city
# Processing Record 12 of Set 7 | ponta delgada
# Processing Record 13 of Set 7 | roma
# Processing Record 14 of Set 7 | bolshiye uki
# city not found. Skipping city
# Processing Record 15 of Set 7 | noumea
# Processing Record 16 of Set 7 | borovoy
# Processing Record 17 of Set 7 | dingle
# Processing Record 18 of Set 7 | harrogate
# Processing Record 19 of Set 7 | mys shmidta
# city not found. Skipping city
# Processing Record 20 of Set 7 | palabuhanratu
# city not found. Skipping city
# Processing Record 21 of Set 7 | kasangulu
# Processing Record 22 of Set 7 | blagoyevo
# Processing Record 23 of Set 7 | grand-lahou
# Processing Record 24 of Set 7 | ryotsu
# Processing Record 25 of Set 7 | puerto madryn
# Processing Record 26 of Set 7 | simao
# Processing Record 27 of Set 7 | camacha
# Processing Record 28 of Set 7 | namibe
# Processing Record 29 of Set 7 | yuancheng
# Processing Record 30 of Set 7 | vanimo
# Processing Record 31 of Set 7 | sao filipe
# Processing Record 32 of Set 7 | bethel
# Processing Record 33 of Set 7 | jega
# Processing Record 34 of Set 7 | nguiu
# city not found. Skipping city
# Processing Record 35 of Set 7 | plettenberg bay
# Processing Record 36 of Set 7 | zarubino
# Processing Record 37 of Set 7 | portland
# Processing Record 38 of Set 7 | effingham
# Processing Record 39 of Set 7 | torbay
# Processing Record 40 of Set 7 | wad rawah
# Processing Record 41 of Set 7 | gariaband
# Processing Record 42 of Set 7 | jalu
# Processing Record 43 of Set 7 | agadir
# Processing Record 44 of Set 7 | kamenskoye
# city not found. Skipping city
# Processing Record 45 of Set 7 | puerto narino
# Processing Record 46 of Set 7 | goma
# Processing Record 47 of Set 7 | sola
# Processing Record 48 of Set 7 | tecoanapa
# Processing Record 49 of Set 7 | harboore
# Processing Record 0 of Set 8 | bonavista
# Processing Record 1 of Set 8 | oksbol
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | armacao dos buzios
# city not found. Skipping city
# Processing Record 4 of Set 8 | kununurra
# Processing Record 5 of Set 8 | la ronge
# Processing Record 6 of Set 8 | mahebourg
# Processing Record 7 of Set 8 | lufkin
# Processing Record 8 of Set 8 | dongsheng
# Processing Record 9 of Set 8 | teya
# Processing Record 10 of Set 8 | tazovskiy
# Processing Record 11 of Set 8 | ribeira grande
# Processing Record 12 of Set 8 | faanui
# Processing Record 13 of Set 8 | san vicente
# Processing Record 14 of Set 8 | nanortalik
# Processing Record 15 of Set 8 | talaya
# Processing Record 16 of Set 8 | turayf
# Processing Record 17 of Set 8 | zlatoustovsk
# city not found. Skipping city
# Processing Record 18 of Set 8 | iwanai
# Processing Record 19 of Set 8 | souillac
# Processing Record 20 of Set 8 | hamilton
# Processing Record 21 of Set 8 | khandagayty
# Processing Record 22 of Set 8 | sosva
# Processing Record 23 of Set 8 | general roca
# Processing Record 24 of Set 8 | nacozari
# Processing Record 25 of Set 8 | kloulklubed
# Processing Record 26 of Set 8 | sisian
# Processing Record 27 of Set 8 | kulhudhuffushi
# Processing Record 28 of Set 8 | cadillac
# Processing Record 29 of Set 8 | thaba nchu
# Processing Record 30 of Set 8 | sinop
# Processing Record 31 of Set 8 | reconquista
# Processing Record 32 of Set 8 | havre-saint-pierre
# Processing Record 33 of Set 8 | vilcun
# Processing Record 34 of Set 8 | nizwa
# Processing Record 35 of Set 8 | shimoda
# Processing Record 36 of Set 8 | port-cartier
# Processing Record 37 of Set 8 | arvika
# Processing Record 38 of Set 8 | port-de-paix
# city not found. Skipping city
# Processing Record 39 of Set 8 | ilulissat
# Processing Record 40 of Set 8 | gornozavodsk
# Processing Record 41 of Set 8 | voloshka
# Processing Record 42 of Set 8 | erzurum
# Processing Record 43 of Set 8 | bontang
# Processing Record 44 of Set 8 | nabire
# Processing Record 45 of Set 8 | malayal
# Processing Record 46 of Set 8 | ust-kuyga
# Processing Record 47 of Set 8 | gaoual
# Processing Record 48 of Set 8 | saint george
# Processing Record 49 of Set 8 | west bay
# Processing Record 0 of Set 9 | ito
# Processing Record 1 of Set 9 | mogadishu
# Processing Record 2 of Set 9 | say
# Processing Record 3 of Set 9 | egvekinot
# Processing Record 4 of Set 9 | norrtalje
# Processing Record 5 of Set 9 | tautira
# Processing Record 6 of Set 9 | tongren
# Processing Record 7 of Set 9 | lusaka
# Processing Record 8 of Set 9 | sorland
# Processing Record 9 of Set 9 | bela vista
# Processing Record 10 of Set 9 | berdigestyakh
# Processing Record 11 of Set 9 | saleaula
# city not found. Skipping city
# Processing Record 12 of Set 9 | soe
# Processing Record 13 of Set 9 | itarema
# Processing Record 14 of Set 9 | ejido
# Processing Record 15 of Set 9 | bikaner
# Processing Record 16 of Set 9 | kabare
# Processing Record 17 of Set 9 | tidore
# city not found. Skipping city
# Processing Record 18 of Set 9 | kawalu
# Processing Record 19 of Set 9 | bubaque
# Processing Record 20 of Set 9 | saint-augustin
# Processing Record 21 of Set 9 | guerrero negro
# Processing Record 22 of Set 9 | passos
# Processing Record 23 of Set 9 | mochudi
# Processing Record 24 of Set 9 | vao
# Processing Record 25 of Set 9 | tashtyp
# Processing Record 26 of Set 9 | phan rang
# city not found. Skipping city
# Processing Record 27 of Set 9 | katesh
# Processing Record 28 of Set 9 | sept-iles
# Processing Record 29 of Set 9 | alekseyevka
# Processing Record 30 of Set 9 | los llanos de aridane
# Processing Record 31 of Set 9 | chicama
# Processing Record 32 of Set 9 | stykkisholmur
# Processing Record 33 of Set 9 | bengkulu
# Processing Record 34 of Set 9 | san cristobal
# Processing Record 35 of Set 9 | utiroa
# city not found. Skipping city
# Processing Record 36 of Set 9 | hammerfest
# Processing Record 37 of Set 9 | xai-xai
# Processing Record 38 of Set 9 | talnakh
# Processing Record 39 of Set 9 | mangai
# Processing Record 40 of Set 9 | pochutla
# Processing Record 41 of Set 9 | pangnirtung
# Processing Record 42 of Set 9 | murgab
# Processing Record 43 of Set 9 | klyavlino
# Processing Record 44 of Set 9 | kegayli
# city not found. Skipping city
# Processing Record 45 of Set 9 | karaton
# Processing Record 46 of Set 9 | inirida
# Processing Record 47 of Set 9 | mahon
# Processing Record 48 of Set 9 | nushki
# Processing Record 49 of Set 9 | ondorhaan
# city not found. Skipping city
# Processing Record 0 of Set 10 | mitsamiouli
# Processing Record 1 of Set 10 | sinnamary
# Processing Record 2 of Set 10 | olafsvik
# Processing Record 3 of Set 10 | bilibino
# Processing Record 4 of Set 10 | truth or consequences
# Processing Record 5 of Set 10 | ust-barguzin
# Processing Record 6 of Set 10 | assare
# Processing Record 7 of Set 10 | dosso
# Processing Record 8 of Set 10 | broome
# Processing Record 9 of Set 10 | jiaozuo
# Processing Record 10 of Set 10 | thunder bay
# Processing Record 11 of Set 10 | seoul
# Processing Record 12 of Set 10 | sungai siput utara
# city not found. Skipping city
# Processing Record 13 of Set 10 | saint-denis
# Processing Record 14 of Set 10 | san patricio
# Processing Record 15 of Set 10 | umm lajj
# Processing Record 16 of Set 10 | laja
# Processing Record 17 of Set 10 | bay roberts
# Processing Record 18 of Set 10 | outjo
# Processing Record 19 of Set 10 | bolungarvik
# city not found. Skipping city
# Processing Record 20 of Set 10 | manuk mangkaw
# Processing Record 21 of Set 10 | sivaki
# Processing Record 22 of Set 10 | pentecoste
# Processing Record 23 of Set 10 | salem
# Processing Record 24 of Set 10 | port lavaca
# Processing Record 25 of Set 10 | bambey
# Processing Record 26 of Set 10 | methoni
# Processing Record 27 of Set 10 | skjervoy
# Processing Record 28 of Set 10 | menomonie
# Processing Record 29 of Set 10 | temaraia
# city not found. Skipping city
# Processing Record 30 of Set 10 | tuatapere
# Processing Record 31 of Set 10 | puerto colombia
# Processing Record 32 of Set 10 | taoudenni
# Processing Record 33 of Set 10 | lusambo
# Processing Record 34 of Set 10 | odienne
# Processing Record 35 of Set 10 | leningradskiy
# Processing Record 36 of Set 10 | kensington
# Processing Record 37 of Set 10 | qasigiannguit
# Processing Record 38 of Set 10 | hereford
# Processing Record 39 of Set 10 | awjilah
# Processing Record 40 of Set 10 | akhmeta
# Processing Record 41 of Set 10 | cayenne
# Processing Record 42 of Set 10 | machico
# Processing Record 43 of Set 10 | tortoli
# Processing Record 44 of Set 10 | valdivia
# Processing Record 45 of Set 10 | rocha
# Processing Record 46 of Set 10 | lahuachaca
# Processing Record 47 of Set 10 | seguela
# Processing Record 48 of Set 10 | guozhen
# Processing Record 49 of Set 10 | middelburg
# Processing Record 0 of Set 11 | sangar
# Processing Record 1 of Set 11 | kinkala
# Processing Record 2 of Set 11 | warqla
# city not found. Skipping city
# Processing Record 3 of Set 11 | saint-georges
# Processing Record 4 of Set 11 | santa isabel do rio negro
# Processing Record 5 of Set 11 | poum
# Processing Record 6 of Set 11 | sarh
# Processing Record 7 of Set 11 | sisophon
# Processing Record 8 of Set 11 | brae
# Processing Record 9 of Set 11 | rundu
# Processing Record 10 of Set 11 | dehloran
# Processing Record 11 of Set 11 | alice springs
# Processing Record 12 of Set 11 | oksfjord
# Processing Record 13 of Set 11 | verkhnyaya toyma
# Processing Record 14 of Set 11 | lazaro cardenas
# Processing Record 15 of Set 11 | buguda
# Processing Record 16 of Set 11 | miles city
# Processing Record 17 of Set 11 | changping
# Processing Record 18 of Set 11 | manado
# Processing Record 19 of Set 11 | kindia
# Processing Record 20 of Set 11 | fuerte olimpo
# Processing Record 21 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 11 | walvis bay
# Processing Record 23 of Set 11 | hihifo
# city not found. Skipping city
# Processing Record 24 of Set 11 | mutsu
# Processing Record 25 of Set 11 | tawang
# Processing Record 26 of Set 11 | bobo dioulasso
# Processing Record 27 of Set 11 | atar
# Processing Record 28 of Set 11 | sabang
# Processing Record 29 of Set 11 | usinsk
# Processing Record 30 of Set 11 | cururupu
# Processing Record 31 of Set 11 | rostaq
# city not found. Skipping city
# Processing Record 32 of Set 11 | imeni morozova
# Processing Record 33 of Set 11 | wana
# Processing Record 34 of Set 11 | tual
# Processing Record 35 of Set 11 | kieta
# Processing Record 36 of Set 11 | mantua
# Processing Record 37 of Set 11 | weiser
# Processing Record 38 of Set 11 | kisumu
# Processing Record 39 of Set 11 | chornukhy
# Processing Record 40 of Set 11 | tatarsk
# Processing Record 41 of Set 11 | athabasca
# Processing Record 42 of Set 11 | mayumba
# Processing Record 43 of Set 11 | alappuzha
# Processing Record 44 of Set 11 | sao joao da barra
# Processing Record 45 of Set 11 | aborlan
# Processing Record 46 of Set 11 | semey
# Processing Record 47 of Set 11 | tapes
# Processing Record 48 of Set 11 | wajir
# Processing Record 49 of Set 11 | defiance
# Processing Record 0 of Set 12 | luanda
# Processing Record 1 of Set 12 | irkutsk
# Processing Record 2 of Set 12 | salinopolis
# Processing Record 3 of Set 12 | minsk mazowiecki
# Processing Record 4 of Set 12 | floyita
# Processing Record 5 of Set 12 | scituate
# Processing Record 6 of Set 12 | ayan
# Processing Record 7 of Set 12 | coolum beach
# Processing Record 8 of Set 12 | solginskiy
# Processing Record 9 of Set 12 | arlit
# Processing Record 10 of Set 12 | mandalgovi
# Processing Record 11 of Set 12 | alofi
# Processing Record 12 of Set 12 | kurumkan
# Processing Record 13 of Set 12 | los alamos
# Processing Record 14 of Set 12 | turan
# Processing Record 15 of Set 12 | calvinia
# Processing Record 16 of Set 12 | moron
# Processing Record 17 of Set 12 | kangaatsiaq
# Processing Record 18 of Set 12 | sanming
# Processing Record 19 of Set 12 | bani
# Processing Record 20 of Set 12 | santiago del estero
# Processing Record 21 of Set 12 | igrim
# Processing Record 22 of Set 12 | dourbali
# Processing Record 23 of Set 12 | keti bandar
# Processing Record 24 of Set 12 | karkaralinsk
# city not found. Skipping city
# Processing Record 25 of Set 12 | tabulbah
# city not found. Skipping city
# Processing Record 26 of Set 12 | lata
# Processing Record 27 of Set 12 | casma
# Processing Record 28 of Set 12 | sao sebastiao do paraiso
# Processing Record 29 of Set 12 | coxim
# Processing Record 30 of Set 12 | myrtle beach
# Processing Record 31 of Set 12 | cassilandia
# Processing Record 32 of Set 12 | khoy
# Processing Record 33 of Set 12 | douentza
# Processing Record 34 of Set 12 | sapa
# Processing Record 35 of Set 12 | kuruman
# Processing Record 36 of Set 12 | puerto cabezas
# Processing Record 37 of Set 12 | kysyl-syr
# Processing Record 38 of Set 12 | darhan
# Processing Record 39 of Set 12 | willmar
# Processing Record 40 of Set 12 | bainbridge
# Processing Record 41 of Set 12 | hastings
# Processing Record 42 of Set 12 | burhanpur
# Processing Record 43 of Set 12 | tumannyy
# city not found. Skipping city
# Processing Record 44 of Set 12 | matadi
# Processing Record 45 of Set 12 | thinadhoo
# Processing Record 46 of Set 12 | dovers
# Processing Record 47 of Set 12 | rodez
# Processing Record 48 of Set 12 | takoradi
# Processing Record 49 of Set 12 | te anau
# Processing Record 0 of Set 13 | kozova
# Processing Record 1 of Set 13 | sechura
# Processing Record 2 of Set 13 | miedzyrzecz
# Processing Record 3 of Set 13 | harper
# Processing Record 4 of Set 13 | bukama
# Processing Record 5 of Set 13 | bawku
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a data frame 
weather_df = pd.DataFrame(city_data)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.to_csv("output/weather_cities.csv", encoding='utf-8', index=False)

# %%
weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 0     kruisfontein         100      ZA  1619368272        43 -34.0033
# 1           hobart          75      AU  1619368272        67 -42.8794
# 2  arraial do cabo           0      BR  1619368272        61 -22.9661
# 3        cape town           0      ZA  1619368272        82 -33.9258
# 4         katsuura          75      JP  1619368273        54  35.1333
#
#         Lng  Max Temp  Wind Speed
# 0   24.7314     72.09        3.65
# 1  147.3294     57.00       10.36
# 2  -42.0278     84.20        9.22
# 3   18.4232     69.01       16.11
# 4  140.3000     57.20       17.27

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
new_coders = "output/weather_cities.csv"
delete_later = pd.read_csv(new_coders)
delete_later.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  560.000000  5.600000e+02  560.000000  560.000000  560.000000
# mean    54.925000  1.619368e+09   64.594643   20.345725   20.074456
# std     37.247489  6.826094e+01   23.948102   32.931941   87.635814
# min      0.000000  1.619368e+09    7.000000  -54.800000 -179.166700
# 25%     20.000000  1.619368e+09   48.000000   -4.650275  -55.108725
# 50%     64.000000  1.619368e+09   70.000000   22.733450   21.417550
# 75%     90.000000  1.619368e+09   83.000000   48.462550   96.271600
# max    100.000000  1.619368e+09  100.000000   78.218600  179.316700
#
#          Max Temp  Wind Speed
# count  560.000000  560.000000
# mean    62.571607    7.958893
# std     21.504355    5.347200
# min     -4.590000    0.200000
# 25%     46.000000    3.932500
# 50%     66.200000    6.820000
# 75%     80.395000   11.120000
# max    107.600000   26.780000

# %%
#Verify if there are any cities with humidity>100%
humidity_cities = delete_later.loc[delete_later["Humidity"] <= 100, :]
humidity_cities['City'].count()
# Out:
# 560

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a dataset:
df_temp=pd.DataFrame({'x_values': delete_later['Lat'], 'y_values': delete_later['Max Temp'] })
# plot
plt.scatter('x_values', 'y_values', data=df_temp, marker='o', edgecolors= 'navy')
plt.title("City Latitude vs. Temperature", pad = 20)
plt.xlabel("Latitude")
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig("Images/LatvsTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a dataset:
df_hum=pd.DataFrame({'x_values': delete_later['Lat'], 'y_values': delete_later['Humidity'] })
# plot
plt.scatter( 'x_values', 'y_values', data=df_hum, marker='o', edgecolors= 'navy')
plt.title("City Latitude vs. Humidity", pad = 20)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
# Show plot
plt.savefig("Images/LatvsHumidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a dataset:
df_cloud=pd.DataFrame({'x_values': delete_later['Lat'], 'y_values': delete_later['Cloudiness'] })
# plot
plt.scatter( 'x_values', 'y_values', data=df_cloud, marker='o', edgecolors= 'navy')
plt.title("City Latitude vs. Temperature", pad = 20)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
# Show plot
plt.savefig("Images/LatvsCloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a dataset:
df_wind=pd.DataFrame({'x_values': delete_later['Lat'], 'y_values': delete_later['Wind Speed'] })
# plot
plt.scatter('x_values', 'y_values', data=df_wind, marker='o', edgecolors= 'navy')
plt.title("City Latitude vs. Wind Speed", pad = 20)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
# Show plot
plt.savefig("Images/LatvsWindspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_df=  delete_later.loc[delete_later['Lat'] >= 0]
x_values = north_df['Lat']
y_values = north_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='violet')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (5,30))
plt.xlabel("Latitude")
plt.ylabel('Max Temperature (F)')
plt.savefig("Images/LinearLatvsTemp.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.8769665742872018

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_df=  delete_later.loc[delete_later['Lat'] < 0]
x_values = south_df['Lat']
y_values = south_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='violet')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-55,80))
plt.xlabel("Latitude")
plt.ylabel('Max Temperature (F)')
plt.savefig("Images/LinearLatvsTemp_South.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.7130870816769271

# %% [markdown]
# #### Analysis :
# There is a strong positive linear relationship with the Temperature and Latitude.
# Therefore, it can be inferred from both graphs that the closer a place is from the equator (latitude = 0) the warmer the place will be.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_df=  delete_later.loc[delete_later['Lat'] >= 0]
x_values = north_df['Lat']
y_values = north_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (55,20))
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
plt.savefig("Images/LineraLatvsHumidity_North.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.24279458040922353

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_df=  delete_later.loc[delete_later['Lat'] < 0]
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,30))
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
plt.savefig("Images/LineraLatvsHumidity_South.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.16907236300985437

# %% [markdown]
# #### Analysis :
# Because the r-value is between 0.1 and 0.3 it can be said that the linear relationship between the Humidity and the Latitude is a weak positive relationship.
# Therefore, it can be inferred that the there is a slight increase in humidity the closer one gets to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_df=  delete_later.loc[delete_later['Lat'] >= 0]
x_values = north_df['Lat']
y_values = north_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='green')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (55,49))
plt.xlabel("Latitude")
plt.ylabel('Cloudiness (%)')
plt.savefig("Images/LineraLatvsCloudiness_North.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.202554384341305

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_df=  delete_later.loc[delete_later['Lat'] < 0]
x_values = south_df['Lat']
y_values = south_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,color='g')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-55,20))
plt.xlabel("Latitude")
plt.ylabel('Cloudiness (%)')
plt.savefig("Images/LineraLatvsCloudiness_South.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.21691620452085658

# %% [markdown]
# #### Analysis :
# Because the r-value is between 0.1 and 0.3 in both graphs, it can be said that there is a weak positive relationship between the Cloudiness percentage and the Latitude.
# Meaning that there is a slight increase in the cloudiness percentage the higher the latitude of a place.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_df=  delete_later.loc[delete_later['Lat'] >= 0]
x_values = north_df['Lat']
y_values = north_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='orange')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (20,25))
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (mph)')
plt.savefig("Images/LineraLatvsWind_North.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.15015446893399517

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_df=  delete_later.loc[delete_later['Lat'] < 0]
x_values = south_df['Lat']
y_values = south_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='orange')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-55,15))
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (mph)')
plt.savefig("Images/LineraLatvsWind_South.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.169168230289292

# %% [markdown]
# #### Analysis :
# Because the r-value for
