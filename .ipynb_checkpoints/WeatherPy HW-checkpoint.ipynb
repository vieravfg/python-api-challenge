# %% [markdown]
# # WeatherPy

# %% [markdown]
# ### Written description of three observable trends based on the data:

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print('Beginning Data Retrieval')
print('-----------------------------')
# Get weather data

#Set up lists to hold reponse info

record_number = 1
set_number = 1
city_data = []
for i, city in enumerate(cities):
    if (i %50 == 0 and i >= 50 ):
        set_number +=1 
        record_number =0
    print(f'Processing Record {record_number} of Set {set_number} | {city}' )
    record_number +=1
    try:
        weather_response = requests.get(query_url + city).json()

        cloudiness = weather_response['clouds']['all']
        country = weather_response['sys']['country']
        date = weather_response['dt']
        humidity = weather_response['main']['humidity']
        lat = weather_response['coord']['lat']
        lng = weather_response['coord']['lon']
        max_tem = weather_response['main']['temp_max']
        wind_speed = weather_response['wind']['speed']
        city_data.append({ "City": city,
                           "Cloudiness": cloudiness,
                            "Country": country,
                            "Date": date,
                            "Humidity": humidity,
                            "Lat": lat,
                            "Lng":lng,
                            "Max Temp": max_tem,
                            "Wind Speed": wind_speed})
    except:
        print('city not found. Skipping city')
        pass
# Inform that Data Retrieval was Completed
print('-----------------------------')
print('Data Retrieval Complete')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sinnar
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | gravdal
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | san jeronimo
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | port augusta
# Processing Record 11 of Set 1 | nome
# Processing Record 12 of Set 1 | tuatapere
# Processing Record 13 of Set 1 | makakilo city
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | karpathos
# Processing Record 17 of Set 1 | kavaratti
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | balotra
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | mount gambier
# Processing Record 24 of Set 1 | kadhan
# Processing Record 25 of Set 1 | bulancak
# Processing Record 26 of Set 1 | fortuna
# Processing Record 27 of Set 1 | deputatskiy
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | illoqqortoormiut
# city not found. Skipping city
# Processing Record 30 of Set 1 | vila franca do campo
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | teahupoo
# Processing Record 38 of Set 1 | loksa
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | potchefstroom
# Processing Record 41 of Set 1 | prince rupert
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | roald
# Processing Record 49 of Set 1 | lashio
# Processing Record 50 of Set 1 | mys shmidta
# city not found. Skipping city
# Processing Record 0 of Set 2 | san cristobal
# Processing Record 1 of Set 2 | chimore
# Processing Record 2 of Set 2 | lagoa
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | sechura
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | lavrentiya
# Processing Record 9 of Set 2 | beloha
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | camacha
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | litovko
# Processing Record 14 of Set 2 | paungde
# Processing Record 15 of Set 2 | amderma
# city not found. Skipping city
# Processing Record 16 of Set 2 | farim
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | kruisfontein
# Processing Record 20 of Set 2 | satitoa
# city not found. Skipping city
# Processing Record 21 of Set 2 | lethem
# Processing Record 22 of Set 2 | vaitupu
# city not found. Skipping city
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | neverkino
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | zabol
# Processing Record 28 of Set 2 | asfi
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | mae hong son
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | christchurch
# Processing Record 34 of Set 2 | camapua
# Processing Record 35 of Set 2 | vitry-le-francois
# Processing Record 36 of Set 2 | pisco
# Processing Record 37 of Set 2 | eskil
# Processing Record 38 of Set 2 | chicama
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | garoua
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | labuhan
# Processing Record 43 of Set 2 | dunedin
# Processing Record 44 of Set 2 | springdale
# Processing Record 45 of Set 2 | blatnica
# Processing Record 46 of Set 2 | amapa
# Processing Record 47 of Set 2 | chara
# Processing Record 48 of Set 2 | jilin
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 0 of Set 3 | belushya guba
# city not found. Skipping city
# Processing Record 1 of Set 3 | silver city
# Processing Record 2 of Set 3 | los llanos de aridane
# Processing Record 3 of Set 3 | vostok
# Processing Record 4 of Set 3 | vega de alatorre
# Processing Record 5 of Set 3 | bratsk
# Processing Record 6 of Set 3 | ninghai
# Processing Record 7 of Set 3 | quatre cocos
# Processing Record 8 of Set 3 | pasighat
# Processing Record 9 of Set 3 | jedburgh
# Processing Record 10 of Set 3 | abalak
# Processing Record 11 of Set 3 | bell ville
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | east wenatchee
# Processing Record 14 of Set 3 | rosita
# Processing Record 15 of Set 3 | janakpur
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | bredasdorp
# Processing Record 18 of Set 3 | gwanda
# Processing Record 19 of Set 3 | cabrero
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | noumea
# Processing Record 22 of Set 3 | broken hill
# Processing Record 23 of Set 3 | grand river south east
# city not found. Skipping city
# Processing Record 24 of Set 3 | banda aceh
# Processing Record 25 of Set 3 | gelnhausen
# Processing Record 26 of Set 3 | kolyvan
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | paka
# Processing Record 31 of Set 3 | miedzyrzecz
# Processing Record 32 of Set 3 | coquimbo
# Processing Record 33 of Set 3 | valladolid
# Processing Record 34 of Set 3 | kaitangata
# Processing Record 35 of Set 3 | beckley
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | port lincoln
# Processing Record 39 of Set 3 | san patricio
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | pangai
# Processing Record 42 of Set 3 | umzimvubu
# city not found. Skipping city
# Processing Record 43 of Set 3 | alenquer
# Processing Record 44 of Set 3 | arlit
# Processing Record 45 of Set 3 | nestorion
# city not found. Skipping city
# Processing Record 46 of Set 3 | arak
# Processing Record 47 of Set 3 | manado
# Processing Record 48 of Set 3 | port hardy
# Processing Record 49 of Set 3 | labutta
# city not found. Skipping city
# Processing Record 0 of Set 4 | souillac
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | gombong
# Processing Record 3 of Set 4 | mareeba
# Processing Record 4 of Set 4 | tsihombe
# city not found. Skipping city
# Processing Record 5 of Set 4 | conceicao da barra
# Processing Record 6 of Set 4 | dikson
# Processing Record 7 of Set 4 | richards bay
# Processing Record 8 of Set 4 | omsukchan
# Processing Record 9 of Set 4 | chumphon
# Processing Record 10 of Set 4 | seymchan
# Processing Record 11 of Set 4 | pastavy
# Processing Record 12 of Set 4 | ngukurr
# city not found. Skipping city
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | atar
# Processing Record 15 of Set 4 | olafsvik
# Processing Record 16 of Set 4 | yar-sale
# Processing Record 17 of Set 4 | sentyabrskiy
# city not found. Skipping city
# Processing Record 18 of Set 4 | attawapiskat
# city not found. Skipping city
# Processing Record 19 of Set 4 | jardim
# Processing Record 20 of Set 4 | cabo san lucas
# Processing Record 21 of Set 4 | ketchikan
# Processing Record 22 of Set 4 | borovskoy
# Processing Record 23 of Set 4 | rawson
# Processing Record 24 of Set 4 | uruana
# Processing Record 25 of Set 4 | ixtapa
# Processing Record 26 of Set 4 | belaya kholunitsa
# Processing Record 27 of Set 4 | abyek
# Processing Record 28 of Set 4 | ekibastuz
# Processing Record 29 of Set 4 | ostrovnoy
# Processing Record 30 of Set 4 | batemans bay
# Processing Record 31 of Set 4 | karratha
# Processing Record 32 of Set 4 | griffith
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | vestmannaeyjar
# Processing Record 35 of Set 4 | puerto madryn
# Processing Record 36 of Set 4 | yabelo
# Processing Record 37 of Set 4 | vao
# Processing Record 38 of Set 4 | tiarei
# Processing Record 39 of Set 4 | lat yao
# Processing Record 40 of Set 4 | hovd
# Processing Record 41 of Set 4 | oleksandrivka
# Processing Record 42 of Set 4 | boa vista
# Processing Record 43 of Set 4 | marcona
# city not found. Skipping city
# Processing Record 44 of Set 4 | taolanaro
# city not found. Skipping city
# Processing Record 45 of Set 4 | pangnirtung
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | tancuayalab
# city not found. Skipping city
# Processing Record 49 of Set 4 | onega
# Processing Record 0 of Set 5 | saint-philippe
# Processing Record 1 of Set 5 | vanavara
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | phon
# Processing Record 4 of Set 5 | vilhena
# Processing Record 5 of Set 5 | victoria
# Processing Record 6 of Set 5 | rocha
# Processing Record 7 of Set 5 | akhtanizovskaya
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | kamina
# Processing Record 10 of Set 5 | dianopolis
# city not found. Skipping city
# Processing Record 11 of Set 5 | guinguineo
# Processing Record 12 of Set 5 | porto novo
# Processing Record 13 of Set 5 | alofi
# Processing Record 14 of Set 5 | rafai
# Processing Record 15 of Set 5 | bereda
# Processing Record 16 of Set 5 | rantepao
# Processing Record 17 of Set 5 | nsoko
# Processing Record 18 of Set 5 | te anau
# Processing Record 19 of Set 5 | fairview
# Processing Record 20 of Set 5 | miles city
# Processing Record 21 of Set 5 | toora-khem
# Processing Record 22 of Set 5 | gat
# Processing Record 23 of Set 5 | palekh
# Processing Record 24 of Set 5 | mangrol
# Processing Record 25 of Set 5 | amga
# Processing Record 26 of Set 5 | plettenberg bay
# Processing Record 27 of Set 5 | maine-soroa
# Processing Record 28 of Set 5 | celestun
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | fraserburgh
# Processing Record 31 of Set 5 | marzuq
# Processing Record 32 of Set 5 | grand gaube
# Processing Record 33 of Set 5 | pemba
# Processing Record 34 of Set 5 | kabinda
# Processing Record 35 of Set 5 | tagnanan
# Processing Record 36 of Set 5 | taurage
# Processing Record 37 of Set 5 | orlik
# Processing Record 38 of Set 5 | katsuura
# Processing Record 39 of Set 5 | college
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | southbridge
# Processing Record 42 of Set 5 | nouadhibou
# Processing Record 43 of Set 5 | nizhneyansk
# city not found. Skipping city
# Processing Record 44 of Set 5 | ouadda
# Processing Record 45 of Set 5 | clyde river
# Processing Record 46 of Set 5 | rosarito
# Processing Record 47 of Set 5 | bitung
# Processing Record 48 of Set 5 | boa viagem
# Processing Record 49 of Set 5 | yuzhno-yeniseyskiy
# city not found. Skipping city
# Processing Record 0 of Set 6 | ituango
# Processing Record 1 of Set 6 | udachnyy
# Processing Record 2 of Set 6 | marquette
# Processing Record 3 of Set 6 | fenoarivo
# Processing Record 4 of Set 6 | coahuayana
# Processing Record 5 of Set 6 | zelenogorskiy
# Processing Record 6 of Set 6 | oranjestad
# Processing Record 7 of Set 6 | lae
# Processing Record 8 of Set 6 | xuddur
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | nemuro
# Processing Record 11 of Set 6 | porterville
# Processing Record 12 of Set 6 | mahajanga
# Processing Record 13 of Set 6 | fairbanks
# Processing Record 14 of Set 6 | ewa beach
# Processing Record 15 of Set 6 | kedrovyy
# Processing Record 16 of Set 6 | leh
# Processing Record 17 of Set 6 | bolungarvik
# city not found. Skipping city
# Processing Record 18 of Set 6 | tocantinopolis
# city not found. Skipping city
# Processing Record 19 of Set 6 | kurchum
# Processing Record 20 of Set 6 | gelemso
# Processing Record 21 of Set 6 | nassjo
# Processing Record 22 of Set 6 | yinchuan
# Processing Record 23 of Set 6 | salamiyah
# Processing Record 24 of Set 6 | punto fijo
# Processing Record 25 of Set 6 | raudeberg
# Processing Record 26 of Set 6 | port hedland
# Processing Record 27 of Set 6 | baglung
# Processing Record 28 of Set 6 | zhanatas
# city not found. Skipping city
# Processing Record 29 of Set 6 | opuwo
# Processing Record 30 of Set 6 | barentsburg
# city not found. Skipping city
# Processing Record 31 of Set 6 | bara
# Processing Record 32 of Set 6 | itarema
# Processing Record 33 of Set 6 | muros
# Processing Record 34 of Set 6 | burma
# Processing Record 35 of Set 6 | sur
# Processing Record 36 of Set 6 | sitka
# Processing Record 37 of Set 6 | ada
# Processing Record 38 of Set 6 | waingapu
# Processing Record 39 of Set 6 | berwick
# Processing Record 40 of Set 6 | coari
# Processing Record 41 of Set 6 | mbanza-ngungu
# Processing Record 42 of Set 6 | tidore
# city not found. Skipping city
# Processing Record 43 of Set 6 | saleaula
# city not found. Skipping city
# Processing Record 44 of Set 6 | abu samrah
# Processing Record 45 of Set 6 | mazatlan
# Processing Record 46 of Set 6 | marsh harbour
# Processing Record 47 of Set 6 | volax
# Processing Record 48 of Set 6 | luanda
# Processing Record 49 of Set 6 | nueva gerona
# Processing Record 0 of Set 7 | san julian
# Processing Record 1 of Set 7 | sao joao da barra
# Processing Record 2 of Set 7 | ponnani
# Processing Record 3 of Set 7 | oum hadjer
# Processing Record 4 of Set 7 | nyagan
# Processing Record 5 of Set 7 | lorengau
# Processing Record 6 of Set 7 | maunabo
# Processing Record 7 of Set 7 | sahrak
# city not found. Skipping city
# Processing Record 8 of Set 7 | krasnoselkup
# Processing Record 9 of Set 7 | bang bo
# Processing Record 10 of Set 7 | marawi
# Processing Record 11 of Set 7 | sioux lookout
# Processing Record 12 of Set 7 | birao
# Processing Record 13 of Set 7 | chernihiv
# Processing Record 14 of Set 7 | salalah
# Processing Record 15 of Set 7 | pacific grove
# Processing Record 16 of Set 7 | aruppukkottai
# Processing Record 17 of Set 7 | asau
# Processing Record 18 of Set 7 | kirakira
# Processing Record 19 of Set 7 | iqaluit
# Processing Record 20 of Set 7 | port macquarie
# Processing Record 21 of Set 7 | zlatoustovsk
# city not found. Skipping city
# Processing Record 22 of Set 7 | codrington
# Processing Record 23 of Set 7 | biltine
# Processing Record 24 of Set 7 | teyateyaneng
# Processing Record 25 of Set 7 | skiros
# city not found. Skipping city
# Processing Record 26 of Set 7 | baoro
# Processing Record 27 of Set 7 | merritt island
# Processing Record 28 of Set 7 | ambanja
# Processing Record 29 of Set 7 | durango
# Processing Record 30 of Set 7 | tamandare
# Processing Record 31 of Set 7 | rungata
# city not found. Skipping city
# Processing Record 32 of Set 7 | rio grande
# Processing Record 33 of Set 7 | punta alta
# Processing Record 34 of Set 7 | osmena
# Processing Record 35 of Set 7 | twentynine palms
# Processing Record 36 of Set 7 | arkhangelsk
# Processing Record 37 of Set 7 | teya
# Processing Record 38 of Set 7 | warqla
# city not found. Skipping city
# Processing Record 39 of Set 7 | sakakah
# Processing Record 40 of Set 7 | tamsweg
# Processing Record 41 of Set 7 | sorvag
# city not found. Skipping city
# Processing Record 42 of Set 7 | jaisalmer
# Processing Record 43 of Set 7 | teguise
# Processing Record 44 of Set 7 | jaciara
# Processing Record 45 of Set 7 | fare
# Processing Record 46 of Set 7 | aykhal
# Processing Record 47 of Set 7 | namibe
# Processing Record 48 of Set 7 | anchorage
# Processing Record 49 of Set 7 | naze
# Processing Record 0 of Set 8 | soyo
# Processing Record 1 of Set 8 | fort abbas
# Processing Record 2 of Set 8 | hokitika
# Processing Record 3 of Set 8 | alta floresta
# Processing Record 4 of Set 8 | tromso
# Processing Record 5 of Set 8 | coxim
# Processing Record 6 of Set 8 | baherden
# Processing Record 7 of Set 8 | piacabucu
# Processing Record 8 of Set 8 | srednekolymsk
# Processing Record 9 of Set 8 | boca do acre
# Processing Record 10 of Set 8 | vila velha
# Processing Record 11 of Set 8 | inuvik
# Processing Record 12 of Set 8 | plessisville
# Processing Record 13 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 8 | lakes entrance
# Processing Record 15 of Set 8 | ilulissat
# Processing Record 16 of Set 8 | geraldton
# Processing Record 17 of Set 8 | doctor pedro p. pena
# city not found. Skipping city
# Processing Record 18 of Set 8 | meulaboh
# Processing Record 19 of Set 8 | qinzhou
# Processing Record 20 of Set 8 | xudat
# Processing Record 21 of Set 8 | tumannyy
# city not found. Skipping city
# Processing Record 22 of Set 8 | vidim
# Processing Record 23 of Set 8 | tarko-sale
# Processing Record 24 of Set 8 | kuche
# city not found. Skipping city
# Processing Record 25 of Set 8 | awbari
# Processing Record 26 of Set 8 | krabi
# Processing Record 27 of Set 8 | kui buri
# Processing Record 28 of Set 8 | dingle
# Processing Record 29 of Set 8 | pontes e lacerda
# Processing Record 30 of Set 8 | kiunga
# Processing Record 31 of Set 8 | limoeiro de anadia
# Processing Record 32 of Set 8 | kalmunai
# Processing Record 33 of Set 8 | arawa
# Processing Record 34 of Set 8 | mackay
# Processing Record 35 of Set 8 | port blair
# Processing Record 36 of Set 8 | tilichiki
# Processing Record 37 of Set 8 | fez
# Processing Record 38 of Set 8 | alencon
# Processing Record 39 of Set 8 | hambantota
# Processing Record 40 of Set 8 | sovetskaya gavan
# Processing Record 41 of Set 8 | ribas do rio pardo
# Processing Record 42 of Set 8 | egvekinot
# Processing Record 43 of Set 8 | buala
# Processing Record 44 of Set 8 | zyryanka
# Processing Record 45 of Set 8 | ballina
# Processing Record 46 of Set 8 | jujuy
# city not found. Skipping city
# Processing Record 47 of Set 8 | georgetown
# Processing Record 48 of Set 8 | ponta do sol
# Processing Record 49 of Set 8 | essenbach
# Processing Record 0 of Set 9 | emba
# Processing Record 1 of Set 9 | palabuhanratu
# city not found. Skipping city
# Processing Record 2 of Set 9 | nyurba
# Processing Record 3 of Set 9 | broome
# Processing Record 4 of Set 9 | severobaykalsk
# Processing Record 5 of Set 9 | ust-kuyga
# Processing Record 6 of Set 9 | saint anthony
# Processing Record 7 of Set 9 | mehamn
# Processing Record 8 of Set 9 | dudinka
# Processing Record 9 of Set 9 | kabo
# Processing Record 10 of Set 9 | cam ranh
# Processing Record 11 of Set 9 | kanniyakumari
# Processing Record 12 of Set 9 | sinnamary
# Processing Record 13 of Set 9 | saldanha
# Processing Record 14 of Set 9 | rincon
# Processing Record 15 of Set 9 | cockburn town
# Processing Record 16 of Set 9 | olga
# Processing Record 17 of Set 9 | rubiataba
# Processing Record 18 of Set 9 | gigmoto
# Processing Record 19 of Set 9 | derzhavinsk
# Processing Record 20 of Set 9 | ribeira grande
# Processing Record 21 of Set 9 | lompoc
# Processing Record 22 of Set 9 | lahad datu
# Processing Record 23 of Set 9 | budisov nad budisovkou
# Processing Record 24 of Set 9 | carutapera
# Processing Record 25 of Set 9 | kitale
# Processing Record 26 of Set 9 | tura
# Processing Record 27 of Set 9 | saint-pierre
# Processing Record 28 of Set 9 | olinda
# Processing Record 29 of Set 9 | sumbe
# Processing Record 30 of Set 9 | ukiah
# Processing Record 31 of Set 9 | avera
# Processing Record 32 of Set 9 | beringovskiy
# Processing Record 33 of Set 9 | matagami
# Processing Record 34 of Set 9 | nantucket
# Processing Record 35 of Set 9 | mocuba
# Processing Record 36 of Set 9 | axim
# Processing Record 37 of Set 9 | viligili
# city not found. Skipping city
# Processing Record 38 of Set 9 | kununurra
# Processing Record 39 of Set 9 | anadyr
# Processing Record 40 of Set 9 | sibiti
# Processing Record 41 of Set 9 | andevoranto
# city not found. Skipping city
# Processing Record 42 of Set 9 | vagur
# Processing Record 43 of Set 9 | tyukalinsk
# Processing Record 44 of Set 9 | makhalino
# Processing Record 45 of Set 9 | jatibarang
# Processing Record 46 of Set 9 | rundu
# Processing Record 47 of Set 9 | changying
# Processing Record 48 of Set 9 | norman wells
# Processing Record 49 of Set 9 | jinchang
# Processing Record 0 of Set 10 | minot
# Processing Record 1 of Set 10 | nueva concepcion
# Processing Record 2 of Set 10 | vanimo
# Processing Record 3 of Set 10 | nelson bay
# Processing Record 4 of Set 10 | nioro
# Processing Record 5 of Set 10 | kamenka
# Processing Record 6 of Set 10 | leningradskiy
# Processing Record 7 of Set 10 | namatanai
# Processing Record 8 of Set 10 | maragogi
# Processing Record 9 of Set 10 | spokane
# Processing Record 10 of Set 10 | dubbo
# Processing Record 11 of Set 10 | tawau
# Processing Record 12 of Set 10 | yorkton
# Processing Record 13 of Set 10 | sao filipe
# Processing Record 14 of Set 10 | ponta delgada
# Processing Record 15 of Set 10 | umm durman
# city not found. Skipping city
# Processing Record 16 of Set 10 | lazaro cardenas
# Processing Record 17 of Set 10 | arman
# Processing Record 18 of Set 10 | ifakara
# Processing Record 19 of Set 10 | nong phai
# Processing Record 20 of Set 10 | chokurdakh
# Processing Record 21 of Set 10 | zapolyarnyy
# Processing Record 22 of Set 10 | antsohihy
# Processing Record 23 of Set 10 | sinjar
# Processing Record 24 of Set 10 | cidreira
# Processing Record 25 of Set 10 | mount darwin
# Processing Record 26 of Set 10 | sisimiut
# Processing Record 27 of Set 10 | caxito
# Processing Record 28 of Set 10 | sao jose da coroa grande
# Processing Record 29 of Set 10 | masuguru
# Processing Record 30 of Set 10 | angoche
# Processing Record 31 of Set 10 | worthing
# Processing Record 32 of Set 10 | scarborough
# Processing Record 33 of Set 10 | daru
# Processing Record 34 of Set 10 | la peca
# Processing Record 35 of Set 10 | hualmay
# Processing Record 36 of Set 10 | carnarvon
# Processing Record 37 of Set 10 | cavalcante
# Processing Record 38 of Set 10 | nkwerre
# Processing Record 39 of Set 10 | okhotsk
# Processing Record 40 of Set 10 | yulara
# Processing Record 41 of Set 10 | lolua
# city not found. Skipping city
# Processing Record 42 of Set 10 | bonavista
# Processing Record 43 of Set 10 | cururupu
# Processing Record 44 of Set 10 | puerto el triunfo
# Processing Record 45 of Set 10 | ganta
# Processing Record 46 of Set 10 | mahabad
# Processing Record 47 of Set 10 | buraydah
# Processing Record 48 of Set 10 | san vicente de canete
# Processing Record 49 of Set 10 | redcliffe
# Processing Record 0 of Set 11 | marzanesti
# Processing Record 1 of Set 11 | soloneshnoye
# Processing Record 2 of Set 11 | kontagora
# Processing Record 3 of Set 11 | ust-nera
# Processing Record 4 of Set 11 | shache
# Processing Record 5 of Set 11 | thinadhoo
# Processing Record 6 of Set 11 | seoul
# Processing Record 7 of Set 11 | miri
# Processing Record 8 of Set 11 | zheleznodorozhnyy
# Processing Record 9 of Set 11 | zlobin
# Processing Record 10 of Set 11 | grindavik
# Processing Record 11 of Set 11 | san rafael
# Processing Record 12 of Set 11 | saint-leu
# Processing Record 13 of Set 11 | samusu
# city not found. Skipping city
# Processing Record 14 of Set 11 | kargil
# Processing Record 15 of Set 11 | yegorlykskaya
# Processing Record 16 of Set 11 | rio gallegos
# Processing Record 17 of Set 11 | yaan
# Processing Record 18 of Set 11 | bargal
# city not found. Skipping city
# Processing Record 19 of Set 11 | ust-kut
# Processing Record 20 of Set 11 | cayenne
# Processing Record 21 of Set 11 | fort nelson
# Processing Record 22 of Set 11 | praia da vitoria
# Processing Record 23 of Set 11 | qui nhon
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | sambava
# Processing Record 26 of Set 11 | davidson
# Processing Record 27 of Set 11 | aswan
# Processing Record 28 of Set 11 | crotone
# Processing Record 29 of Set 11 | calabozo
# Processing Record 30 of Set 11 | aklavik
# Processing Record 31 of Set 11 | tiznit
# Processing Record 32 of Set 11 | chapais
# Processing Record 33 of Set 11 | manzhouli
# Processing Record 34 of Set 11 | yatou
# Processing Record 35 of Set 11 | padang
# Processing Record 36 of Set 11 | paulo ramos
# Processing Record 37 of Set 11 | linxia
# Processing Record 38 of Set 11 | apatou
# Processing Record 39 of Set 11 | mporokoso
# Processing Record 40 of Set 11 | oxapampa
# Processing Record 41 of Set 11 | koutsouras
# Processing Record 42 of Set 11 | atambua
# Processing Record 43 of Set 11 | ola
# Processing Record 44 of Set 11 | listvyanka
# Processing Record 45 of Set 11 | solano
# Processing Record 46 of Set 11 | kavieng
# Processing Record 47 of Set 11 | klyuchi
# Processing Record 48 of Set 11 | stafford
# Processing Record 49 of Set 11 | launceston
# Processing Record 0 of Set 12 | ramon
# Processing Record 1 of Set 12 | kez
# Processing Record 2 of Set 12 | rylsk
# Processing Record 3 of Set 12 | karkaralinsk
# city not found. Skipping city
# Processing Record 4 of Set 12 | comodoro rivadavia
# Processing Record 5 of Set 12 | baturaja
# Processing Record 6 of Set 12 | zonguldak
# Processing Record 7 of Set 12 | sal rei
# Processing Record 8 of Set 12 | xining
# Processing Record 9 of Set 12 | mino
# Processing Record 10 of Set 12 | dali
# Processing Record 11 of Set 12 | tsiroanomandidy
# Processing Record 12 of Set 12 | umba
# Processing Record 13 of Set 12 | rindal
# Processing Record 14 of Set 12 | brainerd
# Processing Record 15 of Set 12 | waipawa
# Processing Record 16 of Set 12 | manuk mangkaw
# Processing Record 17 of Set 12 | nishihara
# Processing Record 18 of Set 12 | damghan
# Processing Record 19 of Set 12 | pandan
# Processing Record 20 of Set 12 | sidi ali
# Processing Record 21 of Set 12 | ardistan
# city not found. Skipping city
# Processing Record 22 of Set 12 | roma
# Processing Record 23 of Set 12 | eydhafushi
# Processing Record 24 of Set 12 | sawang daen din
# Processing Record 25 of Set 12 | ucluelet
# Processing Record 26 of Set 12 | mahina
# Processing Record 27 of Set 12 | yuxia
# Processing Record 28 of Set 12 | ganzhou
# Processing Record 29 of Set 12 | la ronge
# Processing Record 30 of Set 12 | sarab
# Processing Record 31 of Set 12 | puerto padre
# Processing Record 32 of Set 12 | makamba
# Processing Record 33 of Set 12 | olkhovka
# Processing Record 34 of Set 12 | oyem
# Processing Record 35 of Set 12 | hobyo
# Processing Record 36 of Set 12 | manggar
# Processing Record 37 of Set 12 | hami
# Processing Record 38 of Set 12 | flinders
# Processing Record 39 of Set 12 | sarahan
# Processing Record 40 of Set 12 | opobo
# city not found. Skipping city
# Processing Record 41 of Set 12 | izhma
# Processing Record 42 of Set 12 | bangassou
# Processing Record 43 of Set 12 | storslett
# Processing Record 44 of Set 12 | honiara
# Processing Record 45 of Set 12 | kalabugao
# city not found. Skipping city
# Processing Record 46 of Set 12 | kutum
# Processing Record 47 of Set 12 | crab hill
# city not found. Skipping city
# Processing Record 48 of Set 12 | salekhard
# Processing Record 49 of Set 12 | kunming
# Processing Record 0 of Set 13 | hearst
# Processing Record 1 of Set 13 | temaraia
# city not found. Skipping city
# Processing Record 2 of Set 13 | husavik
# Processing Record 3 of Set 13 | ituiutaba
# Processing Record 4 of Set 13 | tera
# Processing Record 5 of Set 13 | santa maria da vitoria
# Processing Record 6 of Set 13 | stuttgart
# Processing Record 7 of Set 13 | maceio
# Processing Record 8 of Set 13 | campbell river
# Processing Record 9 of Set 13 | bairnsdale
# Processing Record 10 of Set 13 | palmer
# Processing Record 11 of Set 13 | bay roberts
# Processing Record 12 of Set 13 | kropotkin
# Processing Record 13 of Set 13 | portland
# Processing Record 14 of Set 13 | ust-kamchatsk
# city not found. Skipping city
# Processing Record 15 of Set 13 | storforshei
# Processing Record 16 of Set 13 | anupgarh
# Processing Record 17 of Set 13 | dukat
# Processing Record 18 of Set 13 | celle
# Processing Record 19 of Set 13 | puerto escondido
# Processing Record 20 of Set 13 | oktyabrskiy
# Processing Record 21 of Set 13 | araguatins
# city not found. Skipping city
# Processing Record 22 of Set 13 | ngunguru
# Processing Record 23 of Set 13 | hirara
# Processing Record 24 of Set 13 | praya
# Processing Record 25 of Set 13 | belaya gora
# Processing Record 26 of Set 13 | najran
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a data frame 
weather_df = pd.DataFrame(city_data)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.to_csv("output/weather_cities.csv", encoding='utf-8', index=False)

# %%
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity      Lat      Lng  \
# 0        sinnar         100      SD  1619813099        16  13.5691  33.5672
# 1  punta arenas          90      CL  1619813099        93 -53.1500 -70.9167
# 2       gravdal          40      NO  1619813099        80  68.1214  13.5031
# 3       ushuaia          75      AR  1619812808        81 -54.8000 -68.3000
# 4    nikolskoye           0      RU  1619813100        45  59.7035  30.7861
#
#    Max Temp  Wind Speed
# 0     95.04        5.01
# 1     42.80        6.91
# 2     32.00       14.97
# 3     41.00        1.01
# 4     41.00        4.47

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
new_coders = "output/weather_cities.csv"

# %%
#Verify if there are any cities with humidity>100%
weather_df.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  576.000000  5.760000e+02  576.000000  576.000000  576.000000
# mean    54.777778  1.619813e+09   69.256944   19.624795   20.989120
# std     39.260945  7.882767e+01   22.977341   33.386736   90.625164
# min      0.000000  1.619813e+09    4.000000  -54.800000 -179.166700
# 25%     15.000000  1.619813e+09   55.000000   -8.778975  -54.812075
# 50%     62.000000  1.619813e+09   76.000000   21.404050   26.173450
# 75%     98.000000  1.619813e+09   87.000000   48.853025  100.340125
# max    100.000000  1.619813e+09  100.000000   78.218600  179.316700
#
#          Max Temp  Wind Speed
# count  576.000000  576.000000
# mean    61.897691    7.380556
# std     20.040379    5.274120
# min      3.880000    0.270000
# 25%     48.200000    3.440000
# 50%     66.200000    5.820000
# 75%     78.505000   10.307500
# max     97.930000   32.210000

# %%
humidity_cities = weather_df.loc[weather_df["Humidity"] <= 100, :]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a dataset:
df_temp=pd.DataFrame({'x_values': weather_df['Lat'], 'y_values': weather_df['Max Temp'] })
# plot
plt.scatter('x_values', 'y_values', data=df_temp, marker='o', edgecolors= 'mintcream')
plt.title("City Latitude vs. Temperature", pad = 20)
plt.xlabel("Latitude")
plt.ylabel('Max Temperature (F)')
plt.grid(True)
plt.savefig("Images/LatvsTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a dataset:
df_hum=pd.DataFrame({'x_values': weather_df['Lat'], 'y_values': weather_df['Humidity'] })
# plot
plt.scatter( 'x_values', 'y_values', data=df_hum, marker='o', edgecolors= 'wheat')
plt.title("City Latitude vs. Humidity", pad = 20)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
# Show plot
plt.savefig("Images/LatvsHumidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a dataset:
df_cloud=pd.DataFrame({'x_values': weather_df['Lat'], 'y_values': weather_df['Cloudiness'] })
# plot
plt.scatter( 'x_values', 'y_values', data=df_cloud, marker='o', edgecolors= 'navy')
plt.title("City Latitude vs. Temperature", pad = 20)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
# Show plot
plt.savefig("Images/LatvsCloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a dataset:
df_wind=pd.DataFrame({'x_values': weather_df['Lat'], 'y_values': weather_df['Wind Speed'] })
# plot
plt.scatter('x_values', 'y_values', data=df_wind, marker='o', edgecolors= 'thistle', color = 'tan')
plt.title("City Latitude vs. Wind Speed", pad = 20)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
# Show plot
plt.savefig("Images/LatvsWindspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_df=  weather_df.loc[weather_df['Lat'] >= 0]
x_values = north_df['Lat']
y_values = north_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='violet')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (5,30))
plt.xlabel("Latitude")
plt.ylabel('Max Temperature (F)')
plt.savefig("Images/LinearLatvsTemp.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.8722714485451428

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_df=  weather_df.loc[weather_df['Lat'] < 0]
x_values = south_df['Lat']
y_values = south_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='violet')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-55,80))
plt.xlabel("Latitude")
plt.ylabel('Max Temperature (F)')
plt.savefig("Images/LinearLatvsTemp_South.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.7286301530198114

# %% [markdown]
# #### Analysis :
# There is a strong linear relationship with the Temperature and Latitude in both Sothern and Northen Hemisphere.
# Therefore, it can be inferred from both graphs that the closer a place is from the equator (latitude = 0) the warmer the place will be.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_df=  weather_df.loc[weather_df['Lat'] >= 0]
x_values = north_df['Lat']
y_values = north_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (55,20))
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
plt.savefig("Images/LineraLatvsHumidity_North.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.18060472264499172

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_df=  weather_df.loc[weather_df['Lat'] < 0]
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-50,30))
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
plt.savefig("Images/LineraLatvsHumidity_South.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.17219368096689108

# %% [markdown]
# #### Analysis :
# Because the r-values of the Humidity (%) vs. Latitude linear regression are between 0.1 and 0.2 it can be said that the linear relationship between the Humidity and the Latitude in the southern and northen hemisphere is a is a weak positive relationship.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_df=  weather_df.loc[weather_df['Lat'] >= 0]
x_values = north_df['Lat']
y_values = north_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='green')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (55,49))
plt.xlabel("Latitude")
plt.ylabel('Cloudiness (%)')
plt.savefig("Images/LineraLatvsCloudiness_North.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.1625500910338641

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_df=  weather_df.loc[weather_df['Lat'] < 0]
x_values = south_df['Lat']
y_values = south_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,color='g')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-55,20))
plt.xlabel("Latitude")
plt.ylabel('Cloudiness (%)')
plt.savefig("Images/LineraLatvsCloudiness_South.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.20152118879257203

# %% [markdown]
# #### Analysis :
# Because the r-value is between 0 and 0.2 in both graphs, it can be said that the relationship between the Cloudiness percentage and the Latitude is very weak.
# Meaning that the correlation between the cloudiness percentage and the Latidude is negligible.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_df=  weather_df.loc[weather_df['Lat'] >= 0]
x_values = north_df['Lat']
y_values = north_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='orange')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (3,19))
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (mph)')
plt.savefig("Images/LineraLatvsWind_North.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: 0.10462601929511167

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_df=  weather_df.loc[weather_df['Lat'] < 0]
x_values = south_df['Lat']
y_values = south_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, color='orange')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (-55,15))
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (mph)')
plt.savefig("Images/LineraLatvsWind_South.png")
plt.show()
print(f"The r-value is: {rvalue}")
# Out:
# The r-value is: -0.16416159190983853

# %% [markdown]
# #### Analysis :
# Because the r-values for the Wind Speed (mph) vs. Latitude Linear Regression are between -0.015 and -0.29 it can be inferred that there is a weak negative linear relationship between the Latitude and the wind speed.

# %% [markdown]
# ### BONUS

# %%
def regression( xvalues , yvalues, color, xlabel, ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xvalues, yvalues)
    regress_values = xvalues * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(xvalues,yvalues, color= color)
    plt.plot(xvalues,regress_values,"r-")
    plt.annotate(line_eq, (-55,15))
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.savefig("Images/LineraLatvsWind_South_Bonus.png")
    plt.show()

# %%
regression( south_df['Lat'],south_df['Wind Speed'], 'red',"Latitude", 'Wind Speed (mph)'  )

# %%
regression(north_df['Lat'], north_df['Wind Speed'], 'blue', "Latitude", 'Winde speed (mph)')
